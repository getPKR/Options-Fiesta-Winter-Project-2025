# %% [markdown]
# ## Question 1 The first question involves arithmetic with a small application of loops. You are given an array of n integers, that is, a1, a2, . . . , an, and you are required to output the maximum and minimum among them. Hint: Try with n = 3, then generalise your argument.

# %%
n = int(input(""))
arr = list(map(int, input("").split()))

min_val = arr[0]
max_val = arr[0]

for i in range(1, n):
    if arr[i] < min_val:
        min_val = arr[i]
    if arr[i] > max_val:
        max_val = arr[i]

print("Minimum value is ", min_val)
print("Maximum value is ", max_val)
# Out:
# Minimum value is  1
# Maximum value is  11

# %% [markdown]
# ## Question 2 This question is for familiarity with strings. You are needed to input a string and check if it is a palindrome. Hint: Read a bit about the two-pointer method.

# %%
word = input()
x = list(word)
n = len(word)

for i in range(n//2):
    if x [i] != x[n-1-i]:
     i = i + 1
     print("Word is not a palindrome")
     break

else:
    print("Word is a palindrome")
# Out:
# Word is a palindrome

# %% [markdown]
# ## Question 3 You will need a basic understanding of sorting for this question. Note that there is a direct Python function to sort a sequence of integers. You are given an array of n integers, that is, 1 a1, a2, . . . , an, and a number x. You need to find a pair of elements whose absolute difference is x. You are assured that such a pair exists in the array. Hint: What if you sort the array?

# %%
arr = list(map(int, input("Enter array elements: ").split()))
x = int(input())

def find_pair_with_difference(arr, x):
    arr.sort()
    i, j = 0, 1
    n = len(arr)

    while j < n:
        dif = arr[j] - arr[i]

        if dif == x and i != j:
            return arr[i], arr[j]
        elif dif < x:
            j += 1
        else:
            i += 1

    return None

print(find_pair_with_difference(arr, x))
# Out:
# (2, 80)

# %% [markdown]
# ## QUESTION 4 You are given an array of length n, and distinct integers a, b, and c. All elements of the array are one of a, b, or c. You are required to sort the array without the use of a conventional sorting algorithm. Hint: Think of three pointers. We do not want you to be acquainted with the numerous data structures in Python. We have specifically prepared the assignment with questions on pointers and sorting algorithms, as it is what you will use the majority of the time: traversing linearly through a time series data.

# %%
n = int(input(""))
arr = list(map(int, input("").split()))
a, b, c = map(int, input("").split())


low = 0
mid = 0
high = n - 1


while mid <= high:
    if arr[mid] == a:
        arr[low], arr[mid] = arr[mid], arr[low]
        low += 1
        mid += 1
    elif arr[mid] == b:
        mid += 1
    else: 
        arr[mid], arr[high] = arr[high], arr[mid]
        high -= 1

print("Sorted array:", arr)
# Out:
# Sorted array: [3, 3, 3, 4, 4, 4, 5, 5, 5]
